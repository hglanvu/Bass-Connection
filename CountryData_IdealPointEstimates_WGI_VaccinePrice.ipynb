# %%
import pandas as pd

# %%
import os

# %%
os.chdir("//Users/huongvu/Documents/Fall 2021/Bass Connection")

# %%
os.getcwd()
# Out:
# '/Users/huongvu/Documents/Fall 2021/Bass Connection'

# %%
df1 = pd.read_csv("Countrydata_Idealpointestimates_WGI_final.csv")

# %%
df2 = pd.read_csv("Vaccine_price_Result.csv")

# %%
df_merge = pd.merge(df1, df2, on=["Country Code"])

# %%
df_merge
# Out:
#       Unnamed: 0 Country Code  Countryname  Year  IdealPointAll  ccode  \
# 0              0          AFG  Afghanistan  2019      -0.753452    700
# 1              0          AFG  Afghanistan  2019      -0.753452    700
# 2              0          AFG  Afghanistan  2019      -0.753452    700
# 3              1          ALB      Albania  2019       1.094502    339
# 4              2          DZA      Algeria  2019      -1.112967    615
# ...          ...          ...          ...   ...            ...    ...
# 1145         164          ZWE     Zimbabwe  2019      -1.174122    552
# 1146         164          ZWE     Zimbabwe  2019      -1.174122    552
# 1147         164          ZWE     Zimbabwe  2019      -1.174122    552
# 1148         164          ZWE     Zimbabwe  2019      -1.174122    552
# 1149         164          ZWE     Zimbabwe  2019      -1.174122    552
#
#       session  NVotesAll Country Code_x  population  ...  \
# ...

# %%
df_merge.to_csv('CountryData_IdealPointEstimates_WGI_VaccinePrice.csv')
