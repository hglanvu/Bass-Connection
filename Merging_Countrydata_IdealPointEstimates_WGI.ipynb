# %%
import pandas as pd

# %%
import os

# %%
os.chdir("//Users/huongvu/Documents/Fall 2021/Bass Connection")

# %%
os.getcwd()
# Out:
# '/Users/huongvu/Documents/Fall 2021/Bass Connection'

# %%
df1 = pd.read_csv("Countrydata&Idealpointestimates.csv")

# %%
df2 = pd.read_csv("WGI_final.csv")

# %%
df_merge = pd.merge(df1, df2, on=["Countryname"])

# %%
df_merge
# Out:
#       Unnamed: 0  Countryname  IdealPointAll  ccode  session  NVotesAll  \
# 0              0  Afghanistan      -0.753452  700.0     73.0       82.0
# 1              0  Afghanistan      -0.753452  700.0     73.0       82.0
# 2              0  Afghanistan      -0.753452  700.0     73.0       82.0
# 3              0  Afghanistan      -0.753452  700.0     73.0       82.0
# 4              0  Afghanistan      -0.753452  700.0     73.0       82.0
# ...          ...          ...            ...    ...      ...        ...
# 1810         164     Zimbabwe      -1.174122  552.0     73.0       72.8
# 1811         164     Zimbabwe      -1.174122  552.0     73.0       72.8
# 1812         164     Zimbabwe      -1.174122  552.0     73.0       72.8
# 1813         164     Zimbabwe      -1.174122  552.0     73.0       72.8
# 1814         164     Zimbabwe      -1.174122  552.0     73.0       72.8
#
#      Country Code_x  population           gdp  gdp_per_capita  ...  \
# ...

# %%
df_merge.to_csv('Countrydata&Idealpointestimates&WGI.csv')
