# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/huongvu/Documents/Fall 2021/Bass Connection/WGI_csv'

# %%
os.chdir("//Users/huongvu/Documents/Fall 2021/Bass Connection/WGI_csv")

# %%
os.getcwd()
# Out:
# '/Users/huongvu/Documents/Fall 2021/Bass Connection/WGI_csv'

# %%
df = pd.read_csv("world_governance_indicator_data.csv")

# %%
df
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1     Afghanistan          AFG
# 2     Afghanistan          AFG
# 3     Afghanistan          AFG
# 4     Afghanistan          AFG
# ...           ...          ...
# 7699     Zimbabwe          ZWE
# 7700     Zimbabwe          ZWE
# 7701     Zimbabwe          ZWE
# 7702     Zimbabwe          ZWE
# 7703     Zimbabwe          ZWE
#
#                                          Indicator Name    Indicator Code  \
# 0                       Control of Corruption: Estimate            CC.EST
# 1              Control of Corruption: Number of Sources         CC.NO.SRC
# 2                Control of Corruption: Percentile Rank        CC.PER.RNK
# 3     Control of Corruption: Percentile Rank, Lower ...  CC.PER.RNK.LOWER
# 4     Control of Corruption: Percentile Rank, Upper ...  CC.PER.RNK.UPPER
# ...                                                 ...               ...
# ...

# %%
df.drop(df.columns.to_series()["1996":"2009"], axis=1)
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1     Afghanistan          AFG
# 2     Afghanistan          AFG
# 3     Afghanistan          AFG
# 4     Afghanistan          AFG
# ...           ...          ...
# 7699     Zimbabwe          ZWE
# 7700     Zimbabwe          ZWE
# 7701     Zimbabwe          ZWE
# 7702     Zimbabwe          ZWE
# 7703     Zimbabwe          ZWE
#
#                                          Indicator Name    Indicator Code  \
# 0                       Control of Corruption: Estimate            CC.EST
# 1              Control of Corruption: Number of Sources         CC.NO.SRC
# 2                Control of Corruption: Percentile Rank        CC.PER.RNK
# 3     Control of Corruption: Percentile Rank, Lower ...  CC.PER.RNK.LOWER
# 4     Control of Corruption: Percentile Rank, Upper ...  CC.PER.RNK.UPPER
# ...                                                 ...               ...
# ...

# %%
dfmelted = df.melt(id_vars=['Country Name', 'Country Code','Indicator Name'], value_vars=['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020'])#.drop('variable',1)

# %%
dfmelted
# Out:
#       Country Name Country Code  \
# 0      Afghanistan          AFG
# 1      Afghanistan          AFG
# 2      Afghanistan          AFG
# 3      Afghanistan          AFG
# 4      Afghanistan          AFG
# ...            ...          ...
# 84739     Zimbabwe          ZWE
# 84740     Zimbabwe          ZWE
# 84741     Zimbabwe          ZWE
# 84742     Zimbabwe          ZWE
# 84743     Zimbabwe          ZWE
#
#                                           Indicator Name variable      value
# 0                        Control of Corruption: Estimate     2010  -1.636177
# 1               Control of Corruption: Number of Sources     2010   9.000000
# 2                 Control of Corruption: Percentile Rank     2010   0.952381
# 3      Control of Corruption: Percentile Rank, Lower ...     2010   0.000000
# 4      Control of Corruption: Percentile Rank, Upper ...     2010   3.809524
# ...                                                  ...      ...        ...
# ...

# %%
dffinal = dfmelted.pivot(values=['value'], index=['Country Name','Country Code','variable'], columns=['Indicator Name'])

# %%
dffinal
# Out:
#                                                              value  \
# Indicator Name                     Control of Corruption: Estimate
# Country Name Country Code variable
# Afghanistan  AFG          2010                           -1.636177
#                           2011                           -1.579174
#                           2012                           -1.419741
#                           2013                           -1.436510
#                           2014                           -1.354829
# ...                                                            ...
# Zimbabwe     ZWE          2016                           -1.259222
#                           2017                           -1.271278
#                           2018                           -1.230871
#                           2019                           -1.236825
#                           2020                           -1.253140
#
# ...

# %%
dffinal.to_csv('WGI_final.csv')
